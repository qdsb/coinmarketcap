# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
import pandas as pd

# %%
driver = webdriver.Firefox()
driver.get('https://coinmarketcap.com/historical/20230825/')
Ranks = []
Coins_List = []
Symbols_List = []
MainLink_List = []
HistoricalLink_List = []
actions = ActionChains(driver)
for i in range(1 , 201):
    Ranks.append(i)
    Coin = driver.find_element(By.XPATH , f'/html/body/div[1]/div[2]/div[2]/div/div[1]/div[3]/div[1]/div[3]/div/table/tbody/tr[{i}]/td[2]/div/a[2]')
    Coins_List.append(Coin.text)
    MainLink_List.append(Coin.get_attribute('href'))
    Symbol = driver.find_element(By.XPATH , f'/html/body/div[1]/div[2]/div[2]/div/div[1]/div[3]/div[1]/div[3]/div/table/tbody/tr[{i}]/td[3]/div').text
    Symbols_List.append(Symbol)
    driver.find_element(By.XPATH , f'/html/body/div[1]/div[2]/div[2]/div/div[1]/div[3]/div[1]/div[3]/div/table/tbody/tr[{i}]/td[11]/div/div/div').click()
    HistoricalLink = driver.find_element(By.XPATH , f'/html/body/div[1]/div[2]/div[2]/div/div[1]/div[3]/div[1]/div[3]/div/table/tbody/tr[{i}]/td[11]/div/div/div[2]/ul/li[3]/a')
    HistoricalLink_List.append(HistoricalLink.get_attribute('href'))
    driver.find_element(By.XPATH , f'/html/body/div[1]/div[2]/div[2]/div/div[1]/div[3]/div[1]/div[3]/div/table/tbody/tr[{i}]/td[10]').click()
    driver.execute_script(f"window.scrollTo(0 , {i} * 47)")
    time.sleep(0.1)
# Out:
# ['https://coinmarketcap.com/currencies/bitcoin/historical-data/',
#  'https://coinmarketcap.com/currencies/ethereum/historical-data/',
#  'https://coinmarketcap.com/currencies/tether/historical-data/',
#  'https://coinmarketcap.com/currencies/bnb/historical-data/',
#  'https://coinmarketcap.com/currencies/xrp/historical-data/',
#  'https://coinmarketcap.com/currencies/usd-coin/historical-data/',
#  'https://coinmarketcap.com/currencies/cardano/historical-data/',
#  'https://coinmarketcap.com/currencies/dogecoin/historical-data/',
#  'https://coinmarketcap.com/currencies/solana/historical-data/',
#  'https://coinmarketcap.com/currencies/tron/historical-data/',
#  'https://coinmarketcap.com/currencies/polkadot-new/historical-data/',
#  'https://coinmarketcap.com/currencies/multi-collateral-dai/historical-data/',
#  'https://coinmarketcap.com/currencies/polygon/historical-data/',
#  'https://coinmarketcap.com/currencies/toncoin/historical-data/',
# ...

# %%
data = pd.DataFrame(list(zip(Ranks , Coins_List , Symbols_List ,MainLink_List , HistoricalLink_List)) , columns =['Rank' , 'Name' , 'Symbol' , 'MainLink' , 'HistoricalLink'])
data.head()
# Out:
#    Rank         Name Symbol                                        MainLink  \
# 0     1      Bitcoin    BTC   https://coinmarketcap.com/currencies/bitcoin/
# 1     2     Ethereum    ETH  https://coinmarketcap.com/currencies/ethereum/
# 2     3  Tether USDt   USDT    https://coinmarketcap.com/currencies/tether/
# 3     4          BNB    BNB       https://coinmarketcap.com/currencies/bnb/
# 4     5          XRP    XRP       https://coinmarketcap.com/currencies/xrp/
#
#                                       HistoricalLink
# 0  https://coinmarketcap.com/currencies/bitcoin/h...
# 1  https://coinmarketcap.com/currencies/ethereum/...
# 2  https://coinmarketcap.com/currencies/tether/hi...
# 3  https://coinmarketcap.com/currencies/bnb/histo...
# 4  https://coinmarketcap.com/currencies/xrp/histo...
